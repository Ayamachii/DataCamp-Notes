# %% [markdown]
# **A python list can inlude different types**

# %%
list1 = ['a','b','c','d','e','f']

# %%
list1[3]
# Out:
# 'd'

# %%
list1[-2]

# %% [markdown]
# ## Slicing

# %% [markdown]
# **The end index is not inclusive**

# %%
list1[0:2]
# Out:
# ['a', 'b']

# %%
list1[:2]
# Out:
# ['a', 'b']

# %%
list1[3:]
# Out:
# ['d', 'e', 'f']

# %%
list1[2]='g'
list1
# Out:
# ['a', 'b', 'g', 'd', 'e', 'f']

# %%
list2=[2,3,4,5,6]

# %%
list1+list2
# Out:
# ['a', 'b', 'g', 'd', 'e', 'f', 2, 3, 4, 5, 6]

# %% [markdown]
# **with normal python lists a '+' sign pastes them together**

# %%
list1+='m'
list1
# Out:
# ['a', 'b', 'g', 'd', 'e', 'f', 'm']

# %%
list1.append('l')
list1
# Out:
# ['a', 'b', 'g', 'd', 'e', 'f', 'm', 'l']

# %%
list1+'p'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 list1+'p'
#
# TypeError: can only concatenate list (not "str") to list

# %%
list1+['u']
# Out:
# ['a', 'b', 'g', 'd', 'e', 'f', 'm', 'l', 'u']

# %%
list1
# Out:
# ['a', 'b', 'g', 'd', 'e', 'f', 'm', 'l']

# %% [markdown]
# **the plus sign is not inplace but the append functn is**

# %%
x = [1,2,3,4]
y=x
y+=[5]
x
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# **x is a refernce, to use a copy of the list so that x is not affected:**

# %%
y=x[:]
y+=[6]
x
# Out:
# [1, 2, 3, 4, 5]

# %%
y
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# **When analyzing data, you'll often want to carry out operations over entire collections of values, and you want to do this fast. With lists, this is a problem**

# %% [markdown]
# **We use NumPy, or Numeric Python**

# %% [markdown]
# NumPy can do all of this so easily because it assumes that your NumPy array can only contain values of a single type. It's either an array of floats, either an array of booleans, and so on. If you do try to create an array with different types, like this for example, the resulting NumPy array will contain a single type, string in this case. The boolean and the float were both converted to strings. Second, you should know that a NumPy array is simply a new kind of Python type, like the float, string and list types from before. This means that it comes with its own methods, which can behave differently than you'd expect

# %%
import numpy as np

# %%
np_list1 = np.array([1,2,3,4])
np_list2 = np.array([5,6,7,8])
np_list1+np_list2
# Out:
# array([ 6,  8, 10, 12])

# %% [markdown]
# **They are added unlike python lists where they were concatenated**

# %%
np_list1[2]
# Out:
# 3

# %% [markdown]
# You can create a 2D numpy array from a regular Python list of lists.

# %%
l2 = np.array([
    [1,2,3],
    [4,5,6]
])

# %%
l2
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
type(l2)
# Out:
# numpy.ndarray

# %%
l2[0]
# Out:
# array([1, 2, 3])

# %%
l2[0][1]
# Out:
# 2

# %%
l2[0,1]
# Out:
# 2

# %%
city = np.array([
    [90,190],
    [70,170],
    [50,150]
])

# %%
city.mean()
# Out:
# 120.0

# %% [markdown]
# **the mean of the 6 numbers**

# %%
city[:,0]
# Out:
# array([90, 70, 50])

# %%
city[:,0].mean()
# Out:
# 70.0

# %% [markdown]
# **this is the mean of the weights only**

# %%
type(city[:,0])
# Out:
# numpy.ndarray

# %%
np.median(city[:,0])
# Out:
# 70.0

# %%
np.mean(city[:,0])
# Out:
# 70.0

# %%
np.std(city[:,0])
# Out:
# 16.32993161855452

# %% [markdown]
# REMEMBER
# print('average = '+ str(avg_variable))

# %%
np.corrcoef(city[:,0], city[:,1])
# Out:
# array([[1., 1.],
#        [1., 1.]])

# %% [markdown]
# FOR NUMPY ND ARRAYS
# an array can only contain a single type. If you change one float to be string, all the array elements will be coerced to strings, to end up with a homogeneous array.

# %% [markdown]
# You can think of the 2D numpy array as an improved list of lists: you can perform calculations on the arrays, like I showed before, and you can do more advanced ways of subsetting.

# %%
m=[[1,2,3],
[2,4,6]]

# %%
m[1,0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 m[1,0]
#
# TypeError: list indices must be integers or slices, not tuple

# %% [markdown]
# **THIS IS AN INVALID SYNTAX IN REGULAR PYTHON LISTS**
# perfectly valid in numPy arrays

# %% [markdown]
# and also pandas dataframe since it is also built on a np array

# %%
np_mat = np.array([[1, 2],
                   [3, 4],
                   [5, 6]])

# %%
np_mat * 2
# Out:
# array([[ 2,  4],
#        [ 6,  8],
#        [10, 12]])

# %%
np_mat + np.array([10, 10])
# Out:
# array([[11, 12],
#        [13, 14],
#        [15, 16]])

# %% [markdown]
# **Notice how it is not concatenation**

# %%
new_row = [7,8]

# %%
np_mat = np.array([[1, 2],
                   [3, 4],
                   [5, 6]])

# %% [markdown]
#     TO ADD A NEW ROW (APPEND) use vstack functn of np but not that by default it is NOT inplace

# %%
np_mat=np.vstack([np_mat,new_row])

# %%
np_mat
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6],
#        [7, 8]])

# %% [markdown]
# THEREFORE YOU HAVE TO ASSIGN IT BACK TO THE ORIGINAL ARRAY

# %% [markdown]
# ## Dictionaries part 1

# %% [markdown]
# Index method in python lists

# %%
a =['w', 'u', 'h']
a.index('u')
# Out:
# 1

# %% [markdown]
# **Dictionary -> map**

# %%
dict = {'italy':120, 'spain':40, 'albania':90}

# %%
dict['italy']
# Out:
# 120

# %% [markdown]
# key instead of index

# %%
n = dict.keys()

# %% [markdown]
# keys are unique if you repeat the saved value is the last one

# %% [markdown]
# Adding an object (similar to maps)

# %%
dict['sealand'] = 900

# %%
dict
# Out:
# {'italy': 120, 'spain': 40, 'albania': 90, 'sealand': 900}

# %% [markdown]
# updating a value to an existing key

# %%
dict['italy'] = 80

# %%
dict
# Out:
# {'italy': 80, 'spain': 40, 'albania': 90, 'sealand': 900}

# %% [markdown]
# checking if italy is in dict

# %%
'italy' in dict
# Out:
# True

# %% [markdown]
# **for a numpy array use del() to delete**
# **while in pandas just use the drop function**

# %% [markdown]
# deleting a pair

# %%
del(dict['spain'])

# %%
dict
# Out:
# {'italy': 80, 'albania': 90, 'sealand': 900}

# %% [markdown]
# Dictionaries can contain key:value pairs where the values are again dictionaries.

# %%
# Dictionary of dictionaries
europe = { 'spain': { 'capital':'madrid', 'population':46.77 },
           'france': { 'capital':'paris', 'population':66.03 },
           'germany': { 'capital':'berlin', 'population':80.62 },
           'norway': { 'capital':'oslo', 'population':5.084 } }


# Print out the capital of France
print(europe['france']['capital'])

# Create sub-dictionary data
data={'capital':'rome','population':59.83}

# Add data to europe under key 'italy'
europe['italy']=data

# Print europe
print(europe)
# Out:
# paris
# {'spain': {'capital': 'madrid', 'population': 46.77}, 'france': {'capital': 'paris', 'population': 66.03}, 'germany': {'capital': 'berlin', 'population': 80.62}, 'norway': {'capital': 'oslo', 'population': 5.084}, 'italy': {'capital': 'rome', 'population': 59.83}}

# %% [markdown]
# # Pandas

# %% [markdown]
# *tabular data*

# %% [markdown]
# since we will need to carry multiple data types in this table, we can not use a numpy array instead we use pandas data structures ex data frame which are built on top of numpy

# %% [raw]
# creating a data frame
# manually from a dictionary
# importing

# %% [markdown]
# **first method**

# %% [markdown]
# keys are the column labels

# %%
dict = {
    'countries':['brazil', 'india', 'rwanda','chad', 'italy'],
    'population':[100, 200, 156, 200, 150],
    'color':['green', 'orange', 'black', 'brown','red']
}

# %%
dict
# Out:
# {'countries': ['brazil', 'india', 'rwanda', 'chad', 'italy'],
#  'population': [100, 200, 156, 200, 150],
#  'color': ['green', 'orange', 'black', 'brown', 'red']}

# %%
import pandas as pd

# %%
pd.DataFrame(dict)
# Out:
#   countries  population   color
# 0    brazil         100   green
# 1     india         200  orange
# 2    rwanda         156   black
# 3      chad         200   brown
# 4     italy         150     red

# %%
c = pd.DataFrame(dict)

# %% [markdown]
# **keys(column labels)**
# **values(data, column by column)**

# %%
c.index=['BR','IN','RW','CH','IT']

# %%
c
# Out:
#    countries  population   color
# BR    brazil         100   green
# IN     india         200  orange
# RW    rwanda         156   black
# CH      chad         200   brown
# IT     italy         150     red

# %% [markdown]
# just a normal python list in this case

# %% [markdown]
#    ## READING FROM CSV

# %%
cs = pd.read_csv('Household-living-costs-price-indexes-September-2022-quarter-group-facts.csv', index_col=0)

# %%
cs
# Out:
#                                year   hlpi  tot_hhs      own  own_wm  \
# hlpi_name
# All households                 2008  allhh  1560859  1087580  574406
# Beneficiary                    2008  benef   185965    71256   39405
# Income quintile 1 (low)        2008  disq1   312376   191470   48424
# Income quintile 2              2008  disq2   312333   196203   84171
# Income quintile 3              2008  disq3   312240   217657  141318
# ...                             ...    ...      ...      ...     ...
# Expenditure quintile 3         2020  expq3   352564   213893  119637
# Expenditure quintile 4         2020  expq4   350182   235256  141104
# Expenditure quintile 5 (high)  2020  expq5   351328   288779  187838
# Māori                          2020  maori   329588   156459  107753
# Superannuitant                 2020  super   388013   314154   38270
#
#                                own_prop  own_wm_prop  prop_hhs   age  size  \
# hlpi_name
# ...

# %%
cs[cs['year'] == 2008]
# Out:
#                                year   hlpi  tot_hhs      own  own_wm  \
# hlpi_name
# All households                 2008  allhh  1560859  1087580  574406
# Beneficiary                    2008  benef   185965    71256   39405
# Income quintile 1 (low)        2008  disq1   312376   191470   48424
# Income quintile 2              2008  disq2   312333   196203   84171
# Income quintile 3              2008  disq3   312240   217657  141318
# Income quintile 4              2008  disq4   312336   229014  147658
# Income quintile 5 (high)       2008  disq5   311574   253235  152835
# Expenditure quintile 1 (low)   2008  expq1   312761   194358   49448
# Expenditure quintile 2         2008  expq2   311973   206342   86390
# Expenditure quintile 3         2008  expq3   311840   194361  108065
# Expenditure quintile 4         2008  expq4   312257   231612  149007
# Expenditure quintile 5 (high)  2008  expq5   312028   260907  181496
# ...

# %% [markdown]
#     **set the index col while you are importing**

# %%
cs[np.logical_and(cs['year']>2008, cs['year']<2015)]
# Out:
#                                year   hlpi  tot_hhs      own  own_wm  \
# hlpi_name
# All households                 2011  allhh  1607228  1048164  523698
# Beneficiary                    2011  benef   197237    56665   27129
# Income quintile 1 (low)        2011  disq1   321848   166355   49952
# Income quintile 2              2011  disq2   321751   187275   77561
# Income quintile 3              2011  disq3   321372   204957  119746
# Income quintile 4              2011  disq4   321507   226916  133454
# Income quintile 5 (high)       2011  disq5   320751   262660  142986
# Expenditure quintile 1 (low)   2011  expq1   321611   173327   35941
# Expenditure quintile 2         2011  expq2   321894   179200   77025
# Expenditure quintile 3         2011  expq3   321367   211728  108496
# Expenditure quintile 4         2011  expq4   320918   224971  134525
# Expenditure quintile 5 (high)  2011  expq5   321439   258938  167710
# ...

# %%
cs=cs.iloc[0:15]

# %%
cs
# Out:
#                                year   hlpi  tot_hhs      own  own_wm  \
# hlpi_name
# All households                 2008  allhh  1560859  1087580  574406
# Beneficiary                    2008  benef   185965    71256   39405
# Income quintile 1 (low)        2008  disq1   312376   191470   48424
# Income quintile 2              2008  disq2   312333   196203   84171
# Income quintile 3              2008  disq3   312240   217657  141318
# Income quintile 4              2008  disq4   312336   229014  147658
# Income quintile 5 (high)       2008  disq5   311574   253235  152835
# Expenditure quintile 1 (low)   2008  expq1   312761   194358   49448
# Expenditure quintile 2         2008  expq2   311973   206342   86390
# Expenditure quintile 3         2008  expq3   311840   194361  108065
# Expenditure quintile 4         2008  expq4   312257   231612  149007
# Expenditure quintile 5 (high)  2008  expq5   312028   260907  181496
# ...

# %%
cs[np.logical_or(cs['year']> 2011, cs['age']<40)]
# Out:
#                                year   hlpi  tot_hhs      own  own_wm  \
# hlpi_name
# All households                 2008  allhh  1560859  1087580  574406
# Beneficiary                    2008  benef   185965    71256   39405
# Income quintile 2              2008  disq2   312333   196203   84171
# Income quintile 3              2008  disq3   312240   217657  141318
# Income quintile 4              2008  disq4   312336   229014  147658
# Income quintile 5 (high)       2008  disq5   311574   253235  152835
# Expenditure quintile 1 (low)   2008  expq1   312761   194358   49448
# Expenditure quintile 2         2008  expq2   311973   206342   86390
# Expenditure quintile 3         2008  expq3   311840   194361  108065
# Expenditure quintile 4         2008  expq4   312257   231612  149007
# Expenditure quintile 5 (high)  2008  expq5   312028   260907  181496
# Māori                          2008  maori   253018   119963   77076
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(np.arange(len(cs['year'])),cs['size'])

# %%
np.mean(cs['age'])
# Out:
# 37.446666666666665

# %%
cs.iloc[0:5,:3]
# Out:
#                          year   hlpi  tot_hhs
# hlpi_name
# All households           2008  allhh  1560859
# Beneficiary              2008  benef   185965
# Income quintile 1 (low)  2008  disq1   312376
# Income quintile 2        2008  disq2   312333
# Income quintile 3        2008  disq3   312240

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers.readers:
#
# ...

# %% [markdown]
# ## Square brackets
# -----

# %% [markdown]
# Column access:

# %%
c
# Out:
#    countries  population   color
# BR    brazil         100   green
# IN     india         200  orange
# RW    rwanda         156   black
# CH      chad         200   brown
# IT     italy         150     red

# %%
c[['countries','color']]
# Out:
#    countries   color
# BR    brazil   green
# IN     india  orange
# RW    rwanda   black
# CH      chad   brown
# IT     italy     red

# %%
c[0:2]
# Out:
#    countries  population   color
# BR    brazil         100   green
# IN     india         200  orange

# %%
type(c[0:2])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# **loc (LABEL-BASED)**

# %%
c.loc[['IN','RW','IT']]
# Out:
#    countries  population   color
# IN     india         200  orange
# RW    rwanda         156   black
# IT     italy         150     red

# %%
c.loc[:,['countries','color']]
# Out:
#    countries   color
# BR    brazil   green
# IN     india  orange
# RW    rwanda   black
# CH      chad   brown
# IT     italy     red

# %%
c.loc[
    ['IT','BR'],
    ['color']
]
# Out:
#     color
# IT    red
# BR  green

# %% [markdown]
# **iloc-> index-based**

# %% [markdown]
# the exact same except for indeces instead of labels

# %%
c.iloc[
    [:2],
    [:2]
      ]
# Out:
#   Cell In[85], line 2
#     [:2],
#      ^
# SyntaxError: invalid syntax

# %% [markdown]
# c.iloc[[0,1],[2,1]]

# %% [markdown]
# the ',' separates the rows from columns whether they are lists or a single entry

# %%
# Print out drives_right column as Series
print(c.iloc[:,2])

# Print out drives_right column as DataFrame
print(c.iloc[:,[2]])

# %% [markdown]
# **NOTICE THE TRANSITION**

# %%
arr = [1,2,3]
arr > 2

# %%
arr = np.array([1,2,3])
bol = arr>2

# %%
arr[bol]

# %% [markdown]
# **THIS IS DONE USING NUMPY ARRAY**

# %%
# Create arrays
my_house = np.array([18.0, 20.0, 10.75, 9.50])
your_house = np.array([14.0, 24.0, 14.25, 9.0])

# my_house greater than or equal to 18
print(my_house >= 18)

# my_house less than your_house
print(my_house < your_house)

# %% [markdown]
# np.logical_and() / np.logical_or() / np.logical_not()

# %% [markdown]
# element wise array boolean

# %%
np.logical_and(my_house > 11, your_house <12)

# %% [markdown]
# if, elif and else **syntax**

# %%
# Define variables
room = "bed"
area = 14.0

# if-elif-else construct for room
if room == "kit" :
    print("looking around in the kitchen.")
elif room == "bed":
    print("looking around in the bedroom.")
else :
    print("looking around elsewhere.")

# if-elif-else construct for area
if area > 15 :
    print("big place!")
elif area > 10:
    print('medium size, nice!')
else :
    print("pretty small.")

# %% [markdown]
# # Mattaku!

# %% [markdown]
# np.logical_and(), np.logical_or() and np.logical_not(), the NumPy variants of the and, or and not operators?

# %%
fam = [180, 155, 165, 160]
for index, height in enumerate(fam):
    print('index of family member is '+ str(index) + ' and their height is '+ str(height))

# %%
for i in fam:
    print('the fam member height is '+str(i))

# %%
fr = "family"
for i in fr:
    print(i.capitalize())

# %% [markdown]
# Iterating over a dictionary

# %%
dict = {
    'countries':['Italy', 'Spain', 'Morocco'],
    'population':[100, 120, 150],
    'color':['green', 'yellow', 'red']
}

# %%
for key,value in dict.items():
    print(key + str(value[0]))
# Out:
# countriesItaly
# population100
# colorgreen

# %% [markdown]
# **DICTIONARIES ARE UNORDERED**

# %% [markdown]
# We can probably think of it as an unordered map

# %%
heights = np.array([150, 160, 170, 180])
weights = np.array([122, 70, 90, 68])

# %%
np_2darr = np.array([heights, weights])

# %%
np_2darr
# Out:
# array([[150, 160, 170, 180],
#        [122,  70,  90,  68]])

# %%
for i in np_2darr:
    print(i)
# Out:
# [150 160 170 180]
# [122  70  90  68]

# %%
for i in np.nditer(np_2darr):
    print(i)
# Out:
# 150
# 160
# 170
# 180
# 122
# 70
# 90
# 68

# %% [markdown]
# **To recap: if you want to iterate over key-value pairs in a dictionary, use the items() method on the dictionary to define the sequence in the for loop. If you want to iterate over all elements in a NumPy array, you should use the nditer() function to specify the sequence. Pay attention here: dictionaries require a method, NumPy arrays use a function.**

# %%
for i in np.arange(5):
    print(i, end = ' ')
# Out:
# 0 1 2 3 4

# %%
for i in np.arange(5):
    print(i, end = '')
# Out:
# 01234

# %% [markdown]
# A pandas series is kinda similar to a labelled one D array

# %% [markdown]
# np.nditer()
# **but**
# df.iterrows()

# %%
word = "ahmed"

# %%
word.capitalize()
# Out:
# 'Ahmed'

# %%
word.upper()
# Out:
# 'AHMED'

# %% [markdown]
# .apply(str.upper)

# %% [markdown]
# seed(): sets the random seed, so that your results are reproducible between simulations. As an argument, it takes an integer of your choosing. If you call the function, no output will be generated.
# rand(): if you don't specify any arguments, it generates a random float between zero and one.

# %% [markdown]
# rand()-> A float between zero and one
# randint(4,8)->chosen from [4,5,6,7]

# %%
cs.head()
# Out:
#                          year   hlpi  tot_hhs      own  own_wm  own_prop  \
# hlpi_name
# All households           2008  allhh  1560859  1087580  574406      69.7
# Beneficiary              2008  benef   185965    71256   39405      38.3
# Income quintile 1 (low)  2008  disq1   312376   191470   48424      61.3
# Income quintile 2        2008  disq2   312333   196203   84171      62.8
# Income quintile 3        2008  disq3   312240   217657  141318      69.7
#
#                          own_wm_prop  prop_hhs   age  size  income  \
# hlpi_name
# All households                  36.8     100.0  35.9   2.7   46704
# Beneficiary                     21.2      11.9  29.9   2.6   23404
# Income quintile 1 (low)         15.5      20.0  40.0   2.3   16747
# Income quintile 2               26.9      20.0  34.7   2.8   31308
# Income quintile 3               45.3      20.0  31.5   3.0   49106
#
#                          expenditure  eqv_income  eqv_exp
# hlpi_name
# ...

# %%
cs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15 entries, All households to All households
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   year         15 non-null     int64
#  1   hlpi         15 non-null     object
#  2   tot_hhs      15 non-null     int64
#  3   own          15 non-null     int64
#  4   own_wm       15 non-null     int64
#  5   own_prop     15 non-null     float64
#  6   own_wm_prop  15 non-null     float64
#  7   prop_hhs     15 non-null     float64
#  8   age          15 non-null     float64
#  9   size         15 non-null     float64
#  10  income       15 non-null     int64
#  11  expenditure  15 non-null     int64
#  12  eqv_income   15 non-null     int64
#  13  eqv_exp      15 non-null     int64
# dtypes: float64(5), int64(8), object(1)
# memory usage: 2.3+ KB

# %%
cs.shape
# Out:
# (15, 14)

# %%
cs.describe()
# Out:
#               year       tot_hhs           own         own_wm   own_prop  \
# count    15.000000  1.500000e+01  1.500000e+01      15.000000  15.000000
# mean   2008.200000  4.686021e+05  3.176784e+05  158586.866667  66.993333
# std       0.774597  4.542580e+05  3.088344e+05  166041.700424  12.869258
# min    2008.000000  1.859650e+05  7.125600e+04   15406.000000  38.300000
# 25%    2008.000000  3.117070e+05  1.943595e+05   63262.000000  62.200000
# 50%    2008.000000  3.122400e+05  2.176570e+05  108065.000000  66.100000
# 75%    2008.000000  3.123560e+05  2.570710e+05  150921.000000  73.750000
# max    2011.000000  1.607228e+06  1.087580e+06  574406.000000  87.600000
#
#        own_wm_prop    prop_hhs        age       size        income  \
# count    15.000000   15.000000  15.000000  15.000000     15.000000
# mean     32.960000   29.820000  37.446667   2.606667  46004.133333
# std      14.820054   28.578468   9.635268   0.353486  22208.776894
# ...

# %%
cs.count
# Out:
# <bound method DataFrame.count of                                year   hlpi  tot_hhs      own  own_wm  \
# hlpi_name
# All households                 2008  allhh  1560859  1087580  574406
# Beneficiary                    2008  benef   185965    71256   39405
# Income quintile 1 (low)        2008  disq1   312376   191470   48424
# Income quintile 2              2008  disq2   312333   196203   84171
# Income quintile 3              2008  disq3   312240   217657  141318
# Income quintile 4              2008  disq4   312336   229014  147658
# Income quintile 5 (high)       2008  disq5   311574   253235  152835
# Expenditure quintile 1 (low)   2008  expq1   312761   194358   49448
# Expenditure quintile 2         2008  expq2   311973   206342   86390
# Expenditure quintile 3         2008  expq3   311840   194361  108065
# Expenditure quintile 4         2008  expq4   312257   231612  149007
# Expenditure quintile 5 (high)  2008  expq5   312028   260907  181496
# ...

# %% [markdown]
# Notice that shpe is an attrivute not a method ,therefore we dontuse two brackets

# %% [markdown]
# shape returns a tuple

# %% [markdown]
# . Introducing DataFrames
# Hi, I'm Richie. I'll be your tour guide through the world of pandas.
#
# 2. What's the point of pandas?
# pandas is a Python package for data manipulation. It can also be used for data visualization; we'll get to that in Chapter 4.
#
# 3. Course outline
# We'll start by talking about DataFrames, which form the core of pandas. In chapter 2, we'll discuss aggregating data to gather insights. In chapter 3, you'll learn all about slicing and indexing to subset DataFrames. Finally, you'll visualize your data, deal with missing data, and read data into a DataFrame. Let's dive in.
#
# 4. pandas is built on NumPy and Matplotlib
# pandas is built on top of two essential Python packages, NumPy and Matplotlib. Numpy provides multidimensional array objects for easy data manipulation that pandas uses to store data, and Matplotlib has powerful data visualization capabilities that pandas takes advantage of.
#
# 5. pandas is popular
# pandas has millions of users, with PyPi recording about 14 million downloads in December 2019. This represents almost the entire Python data science community!
#
# 1 https://pypistats.org/packages/pandas
# 6. Rectangular data
# There are several ways to store data for analysis, but rectangular data, sometimes called "tabular data" is the most common form. In this example, with dogs, each observation, or each dog, is a row, and each variable, or each dog property, is a column. pandas is designed to work with rectangular data like this.
#
# 7. pandas DataFrames
# In pandas, rectangular data is represented as a DataFrame object. Every programming language used for data analysis has something similar to this. R also has DataFrames, while SQL has database tables. Every value within a column has the same data type, either text or numeric, but different columns can contain different data types.
#
# 8. Exploring a DataFrame: .head()
# When you first receive a new dataset, you want to quickly explore it and get a sense of its contents. pandas has several methods for this. The first is head, which returns the first few rows of the DataFrame. We only had seven rows to begin with, so it's not super exciting, but this becomes very useful if you have many rows.
#
# 9. Exploring a DataFrame: .info()
# The info method displays the names of columns, the data types they contain, and whether they have any missing values.
#
# 10. Exploring a DataFrame: .shape
# A DataFrame's shape attribute contains a tuple that holds the number of rows followed by the number of columns. Since this is an attribute instead of a method, you write it without parentheses.
#
# 11. Exploring a DataFrame: .describe()
# The describe method computes some summary statistics for numerical columns, like mean and median. "count" is the number of non-missing values in each column. describe is good for a quick overview of numeric variables, but if you want more control, you'll see how to perform more specific calculations later in the course.
#
# 12. Components of a DataFrame: .values
# DataFrames consist of three different components, accessible using attributes. The values attribute, as you might expect, contains the data values in a 2-dimensional NumPy array.
#
# 13. Components of a DataFrame: .columns and .index
# The other two components of a DataFrame are labels for columns and rows. The columns attribute contains column names, and the index attribute contains row numbers or row names. Be careful, since row labels are stored in dot-index, not in dot-rows. Notice that these are Index objects, which we'll cover in Chapter 3. This allows for flexibility in labels. For example, the dogs data uses row numbers, but row names are also possible.
#
# 14. pandas Philosophy
# Python has a semi-official philosophy on how to write good code called The Zen of Python. One suggestion is that given a programming problem, there should only be one obvious solution. As you go through this course, bear in mind that pandas deliberately doesn't follow this philosophy. Instead, there are often multiple ways to solve a problem, leaving you to choose the best. In this respect, pandas is like a Swiss Army Knife, giving you a variety of tools, making it incredibly powerful, but more difficult to learn. In this course, we aim for a more streamlined approach to pandas, only covering the most important ways of doing things.
#
# 1 https://www.python.org/dev/peps/pep-0020/

# %%
cs.values
# Out:
# array([[2008, 'allhh', 1560859, 1087580, 574406, 69.7, 36.8, 100.0, 35.9,
#         2.7, 46704, 42394, 26869, 25132],
#        [2008, 'benef', 185965, 71256, 39405, 38.3, 21.2, 11.9, 29.9, 2.6,
#         23404, 25270, 14258, 15824],
#        [2008, 'disq1', 312376, 191470, 48424, 61.3, 15.5, 20.0, 40.0,
#         2.3, 16747, 21145, 13402, 14408],
#        [2008, 'disq2', 312333, 196203, 84171, 62.8, 26.9, 20.0, 34.7,
#         2.8, 31308, 29855, 18917, 18266],
#        [2008, 'disq3', 312240, 217657, 141318, 69.7, 45.3, 20.0, 31.5,
#         3.0, 49106, 46561, 26870, 24672],
#        [2008, 'disq4', 312336, 229014, 147658, 73.3, 47.3, 20.0, 35.3,
#         2.6, 61674, 52776, 36691, 31958],
#        [2008, 'disq5', 311574, 253235, 152835, 81.3, 49.1, 20.0, 39.3,
#         2.5, 96861, 72822, 55637, 42932],
#        [2008, 'expq1', 312761, 194358, 49448, 62.1, 15.8, 20.0, 38.7,
#         2.5, 23680, 16413, 15190, 11015],
# ...

# %%
type(cs.values)
# Out:
# numpy.ndarray

# %%
cs.index
# Out:
# Index(['All households', 'Beneficiary', 'Income quintile 1 (low)',
#        'Income quintile 2', 'Income quintile 3', 'Income quintile 4',
#        'Income quintile 5 (high)', 'Expenditure quintile 1 (low)',
#        'Expenditure quintile 2', 'Expenditure quintile 3',
#        'Expenditure quintile 4', 'Expenditure quintile 5 (high)', 'Māori',
#        'Superannuitant', 'All households'],
#       dtype='object', name='hlpi_name')

# %%
type(cs.index)
# Out:
# pandas.core.indexes.base.Index

# %%
cs.columns
# Out:
# Index(['year', 'hlpi', 'tot_hhs', 'own', 'own_wm', 'own_prop', 'own_wm_prop',
#        'prop_hhs', 'age', 'size', 'income', 'expenditure', 'eqv_income',
#        'eqv_exp'],
#       dtype='object')

# %%
type(cs.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
small_cs=cs[:10][:10]

# %%
small_cs
# Out:
#                               year   hlpi  tot_hhs      own  own_wm  own_prop  \
# hlpi_name
# All households                2008  allhh  1560859  1087580  574406      69.7
# Beneficiary                   2008  benef   185965    71256   39405      38.3
# Income quintile 1 (low)       2008  disq1   312376   191470   48424      61.3
# Income quintile 2             2008  disq2   312333   196203   84171      62.8
# Income quintile 3             2008  disq3   312240   217657  141318      69.7
# Income quintile 4             2008  disq4   312336   229014  147658      73.3
# Income quintile 5 (high)      2008  disq5   311574   253235  152835      81.3
# Expenditure quintile 1 (low)  2008  expq1   312761   194358   49448      62.1
# Expenditure quintile 2        2008  expq2   311973   206342   86390      66.1
# Expenditure quintile 3        2008  expq3   311840   194361  108065      62.3
#
#                               own_wm_prop  prop_hhs   age  size  income  \
# hlpi_name
# ...

# %%
small_cs.columns
# Out:
# Index(['year', 'hlpi', 'tot_hhs', 'own', 'own_wm', 'own_prop', 'own_wm_prop',
#        'prop_hhs', 'age', 'size', 'income', 'expenditure', 'eqv_income',
#        'eqv_exp'],
#       dtype='object')

# %%
small_cs.index
# Out:
# Index(['All households', 'Beneficiary', 'Income quintile 1 (low)',
#        'Income quintile 2', 'Income quintile 3', 'Income quintile 4',
#        'Income quintile 5 (high)', 'Expenditure quintile 1 (low)',
#        'Expenditure quintile 2', 'Expenditure quintile 3'],
#       dtype='object', name='hlpi_name')

# %%
small_cs.values
# Out:
# array([[2008, 'allhh', 1560859, 1087580, 574406, 69.7, 36.8, 100.0, 35.9,
#         2.7, 46704, 42394, 26869, 25132],
#        [2008, 'benef', 185965, 71256, 39405, 38.3, 21.2, 11.9, 29.9, 2.6,
#         23404, 25270, 14258, 15824],
#        [2008, 'disq1', 312376, 191470, 48424, 61.3, 15.5, 20.0, 40.0,
#         2.3, 16747, 21145, 13402, 14408],
#        [2008, 'disq2', 312333, 196203, 84171, 62.8, 26.9, 20.0, 34.7,
#         2.8, 31308, 29855, 18917, 18266],
#        [2008, 'disq3', 312240, 217657, 141318, 69.7, 45.3, 20.0, 31.5,
#         3.0, 49106, 46561, 26870, 24672],
#        [2008, 'disq4', 312336, 229014, 147658, 73.3, 47.3, 20.0, 35.3,
#         2.6, 61674, 52776, 36691, 31958],
#        [2008, 'disq5', 311574, 253235, 152835, 81.3, 49.1, 20.0, 39.3,
#         2.5, 96861, 72822, 55637, 42932],
#        [2008, 'expq1', 312761, 194358, 49448, 62.1, 15.8, 20.0, 38.7,
#         2.5, 23680, 16413, 15190, 11015],
# ...

# %%
cs.sort_values('age')
# Out:
#                                year   hlpi  tot_hhs      own  own_wm  \
# hlpi_name
# Māori                          2008  maori   253018   119963   77076
# Beneficiary                    2008  benef   185965    71256   39405
# Income quintile 3              2008  disq3   312240   217657  141318
# Expenditure quintile 3         2008  expq3   311840   194361  108065
# Income quintile 2              2008  disq2   312333   196203   84171
# Expenditure quintile 4         2008  expq4   312257   231612  149007
# Income quintile 4              2008  disq4   312336   229014  147658
# All households                 2008  allhh  1560859  1087580  574406
# Expenditure quintile 2         2008  expq2   311973   206342   86390
# All households                 2011  allhh  1607228  1048164  523698
# Expenditure quintile 5 (high)  2008  expq5   312028   260907  181496
# Expenditure quintile 1 (low)   2008  expq1   312761   194358   49448
# ...

# %% [markdown]
# *sorting the rows ascendingly acc to a specific col(criterion)*

# %%
cs.sort_values('age', ascending=False)
# Out:
#                                year   hlpi  tot_hhs      own  own_wm  \
# hlpi_name
# Superannuitant                 2008  super   300243   263054   15406
# Income quintile 1 (low)        2008  disq1   312376   191470   48424
# Income quintile 5 (high)       2008  disq5   311574   253235  152835
# Expenditure quintile 1 (low)   2008  expq1   312761   194358   49448
# Expenditure quintile 5 (high)  2008  expq5   312028   260907  181496
# All households                 2011  allhh  1607228  1048164  523698
# Expenditure quintile 2         2008  expq2   311973   206342   86390
# All households                 2008  allhh  1560859  1087580  574406
# Income quintile 4              2008  disq4   312336   229014  147658
# Expenditure quintile 4         2008  expq4   312257   231612  149007
# Income quintile 2              2008  disq2   312333   196203   84171
# Expenditure quintile 3         2008  expq3   311840   194361  108065
# ...

# %% [markdown]
# *descendingly*

# %%
cs.sort_values(['age','size'])
# Out:
#                                year   hlpi  tot_hhs      own  own_wm  \
# hlpi_name
# Māori                          2008  maori   253018   119963   77076
# Beneficiary                    2008  benef   185965    71256   39405
# Income quintile 3              2008  disq3   312240   217657  141318
# Expenditure quintile 3         2008  expq3   311840   194361  108065
# Income quintile 2              2008  disq2   312333   196203   84171
# Expenditure quintile 4         2008  expq4   312257   231612  149007
# Income quintile 4              2008  disq4   312336   229014  147658
# All households                 2008  allhh  1560859  1087580  574406
# Expenditure quintile 2         2008  expq2   311973   206342   86390
# All households                 2011  allhh  1607228  1048164  523698
# Expenditure quintile 5 (high)  2008  expq5   312028   260907  181496
# Expenditure quintile 1 (low)   2008  expq1   312761   194358   49448
# ...

# %% [markdown]
# *sorting acc to multiple criteria*

# %%
cs.sort_values(['age','size'], ascending=[True, False])
# Out:
#                                year   hlpi  tot_hhs      own  own_wm  \
# hlpi_name
# Māori                          2008  maori   253018   119963   77076
# Beneficiary                    2008  benef   185965    71256   39405
# Income quintile 3              2008  disq3   312240   217657  141318
# Expenditure quintile 3         2008  expq3   311840   194361  108065
# Income quintile 2              2008  disq2   312333   196203   84171
# Expenditure quintile 4         2008  expq4   312257   231612  149007
# Income quintile 4              2008  disq4   312336   229014  147658
# All households                 2008  allhh  1560859  1087580  574406
# Expenditure quintile 2         2008  expq2   311973   206342   86390
# All households                 2011  allhh  1607228  1048164  523698
# Expenditure quintile 5 (high)  2008  expq5   312028   260907  181496
# Expenditure quintile 1 (low)   2008  expq1   312761   194358   49448
# ...

# %%
cs
# Out:
#                                year   hlpi  tot_hhs      own  own_wm  \
# hlpi_name
# All households                 2008  allhh  1560859  1087580  574406
# Beneficiary                    2008  benef   185965    71256   39405
# Income quintile 1 (low)        2008  disq1   312376   191470   48424
# Income quintile 2              2008  disq2   312333   196203   84171
# Income quintile 3              2008  disq3   312240   217657  141318
# Income quintile 4              2008  disq4   312336   229014  147658
# Income quintile 5 (high)       2008  disq5   311574   253235  152835
# Expenditure quintile 1 (low)   2008  expq1   312761   194358   49448
# Expenditure quintile 2         2008  expq2   311973   206342   86390
# Expenditure quintile 3         2008  expq3   311840   194361  108065
# Expenditure quintile 4         2008  expq4   312257   231612  149007
# Expenditure quintile 5 (high)  2008  expq5   312028   260907  181496
# ...

# %% [markdown]
# Notice that the sorting is not inplace

# %% [markdown]
# To filter on multiple categorical data -> isin() methos

# %%
cs[cs['year'].isin([2008, 2011])]
# Out:
#                                year   hlpi  tot_hhs      own  own_wm  \
# hlpi_name
# All households                 2008  allhh  1560859  1087580  574406
# Beneficiary                    2008  benef   185965    71256   39405
# Income quintile 1 (low)        2008  disq1   312376   191470   48424
# Income quintile 2              2008  disq2   312333   196203   84171
# Income quintile 3              2008  disq3   312240   217657  141318
# Income quintile 4              2008  disq4   312336   229014  147658
# Income quintile 5 (high)       2008  disq5   311574   253235  152835
# Expenditure quintile 1 (low)   2008  expq1   312761   194358   49448
# Expenditure quintile 2         2008  expq2   311973   206342   86390
# Expenditure quintile 3         2008  expq3   311840   194361  108065
# Expenditure quintile 4         2008  expq4   312257   231612  149007
# Expenditure quintile 5 (high)  2008  expq5   312028   260907  181496
# ...

# %%
cs["year_ink"] = cs["year"]*0.001
# Out:
# C:\Users\ayaey\AppData\Local\Temp\ipykernel_15576\308684609.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cs["year_ink"] = cs["year"]*0.001

# %% [markdown]
# Taking the minimum and maximum of a column of dates is handy for figuring out what time period your data covers.
# using .min() and .max()

# %% [markdown]
# "IQR" is short for inter-quartile range, which is the 75th percentile minus the 25th percentile. It's an alternative to standard deviation that is helpful if your data contains outliers.

# %% [markdown]
# # Import NumPy and create custom IQR function
# import numpy as np
# def iqr(column):
#     return column.quantile(0.75) - column.quantile(0.25)
#
# # Update to print IQR and median of temperature_c, fuel_price_usd_per_l, & unemployment
# print(sales[["temperature_c", "fuel_price_usd_per_l", "unemployment"]].agg([iqr, np.median]))
